# %% [markdown]
# Check Data Type (1.3.1) - Problem
# Data Types
# Problem Statement:
# Check the data type of the variable job_title which is set to 'Data Scientist'

# %%
job_title = "Data Scientist"
type (job_title)
# Out:
# str
